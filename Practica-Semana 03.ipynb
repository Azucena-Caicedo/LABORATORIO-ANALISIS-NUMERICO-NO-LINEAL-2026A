# %%
import math                              # Funciones matematicas
import matplotlib.pyplot as plt          # Para graficar

# METODO DE NEWTON CLASICO Y MODIFICADO


# PARTE A. COMPLETAR EN CLASE
# Aqui se define la funcion y su derivada


def f(x):
    # Completar en clase:
    # Ejemplo 1:
    return math.cos(2*x)**2 - x**2
    


def df(x):
    # Completar en clase:
    # Derivada del Ejemplo 1:
    return -4*math.cos(2*x)*math.sin(2*x) - 2*x  
   



# PARTE B. COMPLETAR EN CLASE
# Datos iniciales


x0 = 0.75                 # Punto inicial
tol = 1e-10               # Tolerancia
max_iter = 100            # Maximo numero de iteraciones



# PARTE C. BLOQUE BASE: NEWTON CLASICO


def newton_clasico(x0, tol=1e-10, max_iter=100):
    x = x0
    errores = []                                 #Lista para guardar errores
    iteraciones = []                             #Lista para guardar las iteraciones x_k

    print("\nMETODO DE NEWTON CLASICO")
    print("Iter |      x_k       |     f(x_k)      |     f'(x_k)     | Error absoluto")
    print("-------------------------------------------------------------------------------")

    for k in range(max_iter):                      
        fx = f(x)                                 #Evalua la función en x_k
        dfx = df(x)                               #Evalúa f' en x_k

        if dfx == 0:                              #Evita la división por cero
            print("La derivada se hizo cero. El metodo se detiene.")
            break

        # FORMULA DE NEWTON CLASICO
        x_new = x - fx / dfx                    

        error = abs(x_new - x)                  # Error absoluto entre iteraciones

        print(f"{k:4d} | {x:14.10f} | {fx:14.10e} | {dfx:14.10e} | {error:14.10e}")

        errores.append(error)                  # guardar el error
        iteraciones.append(x)                  # guardar x_k

        if error < tol:                        #criterio de parada
            x = x_new                          #actualiza antes de salir
            iteraciones.append(x)              # guarda la última aproximación
            break

        x = x_new                              #actualiza x para la siguiente iteración

    print("\nRespuesta final Newton clasico:")
    print(f"Raiz aproximada = {x:.12f}")
    print(f"Numero de iteraciones = {k+1}")

    return x, errores, iteraciones



# PARTE D. BLOQUE BASE: NEWTON MODIFICADO


def newton_modificado(x0, tol=1e-10, max_iter=100):
    x = x0
    errores = []
    iteraciones = []

    # DERIVADA FIJA EN x0
    dfx0 = df(x0)

    print("\nMETODO DE NEWTON MODIFICADO")
    print("Iter |      x_k       |     f(x_k)      |   f'(x0) fija    | Error absoluto")
    print("-------------------------------------------------------------------------------")

    if dfx0 == 0:
        print("La derivada inicial es cero. El metodo no puede comenzar.")
        return x, errores, iteraciones

    for k in range(max_iter):
        fx = f(x)                             #Evaluar la función en x_k

        # FORMULA DE NEWTON MODIFICADO
        x_new = x - fx / dfx0   

        error = abs(x_new - x)                #error absoluto de las iteraciones

        print(f"{k:4d} | {x:14.10f} | {fx:14.10e} | {dfx0:14.10e} | {error:14.10e}")

        errores.append(error)                  # guarda el error
        iteraciones.append(x)                  #guarda las iteraciones

        if error < tol:                         
            x = x_new
            iteraciones.append(x)
            break

        x = x_new

    print("\nRespuesta final Newton modificado:")
    print(f"Raiz aproximada = {x:.12f}")
    print(f"Numero de iteraciones = {k+1}")

    return x, errores, iteraciones



# PARTE E. EJECUCION


raiz_newton, err_newton, xs_newton = newton_clasico(x0, tol, max_iter)              # Ejecuta el método de newton clásico
raiz_mod, err_mod, xs_mod = newton_modificado(x0, tol, max_iter)                    # Ejecuta el método de newton mdificado



# PARTE F. GRAFICA


plt.figure(figsize=(8, 5))
plt.semilogy(range(1, len(err_newton)+1), err_newton, marker='o', label='Newton clasico')
plt.semilogy(range(1, len(err_mod)+1), err_mod, marker='s', label='Newton modificado')
plt.xlabel('Iteracion')
plt.ylabel('Error absoluto')
plt.title('Comparacion de convergencia')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# METODO DE NEWTON CLASICO
# Iter |      x_k       |     f(x_k)      |     f'(x_k)     | Error absoluto
# -------------------------------------------------------------------------------
#    0 |   0.7500000000 | -5.5749624830e-01 | -1.7822400161e+00 | 3.1280649254e-01
#    1 |   0.4371935075 | 2.2034204473e-01 | -2.8427944783e+00 | 7.7508960429e-02
#    2 |   0.5147024679 | 6.4524651305e-04 | -2.7959369246e+00 | 2.3078006781e-04
#    3 |   0.5149332480 | 4.6685946442e-08 | -2.7955320812e+00 | 1.6700200556e-08
#    4 |   0.5149332647 | 2.7755575616e-16 | -2.7955320519e+00 | 1.1102230246e-16
#
# Respuesta final Newton clasico:
# Raiz aproximada = 0.514933264661
# Numero de iteraciones = 5
#
# METODO DE NEWTON MODIFICADO
# Iter |      x_k       |     f(x_k)      |   f'(x0) fija    | Error absoluto
# -------------------------------------------------------------------------------
#    0 |   0.7500000000 | -5.5749624830e-01 | -1.7822400161e+00 | 3.1280649254e-01
#    1 |   0.4371935075 | 2.2034204473e-01 | -1.7822400161e+00 | 1.2363208251e-01
#    2 |   0.5608255900 | -1.2599950141e-01 | -1.7822400161e+00 | 7.0697268755e-02
#    3 |   0.4901283212 | 6.9810922803e-02 | -1.7822400161e+00 | 3.9170326203e-02
#    4 |   0.5292986474 | -3.9963696209e-02 | -1.7822400161e+00 | 2.2423296440e-02
#    5 |   0.5068753510 | 2.2580739273e-02 | -1.7822400161e+00 | 1.2669864367e-02
#    6 |   0.5195452153 | -1.2873704143e-02 | -1.7822400161e+00 | 7.2233279619e-03
#    7 |   0.5123218874 | 7.3060973551e-03 | -1.7822400161e+00 | 4.0993902555e-03
#    8 |   0.5164212776 | -4.1578267725e-03 | -1.7822400161e+00 | 2.3329219044e-03
#    9 |   0.5140883557 | 2.3625944452e-03 | -1.7822400161e+00 | 1.3256320270e-03
#   10 |   0.5154139878 | -1.3436732509e-03 | -1.7822400161e+00 | 7.5392384793e-04
#   11 |   0.5146600639 | 7.6380692597e-04 | -1.7822400161e+00 | 4.2856569208e-04
#   12 |   0.5150886296 | -4.3430646611e-04 | -1.7822400161e+00 | 2.4368573378e-04
#   13 |   0.5148449439 | 2.4691043561e-04 | -1.7822400161e+00 | 1.3853938492e-04
#   14 |   0.5149834833 | -1.4038549015e-04 | -1.7822400161e+00 | 7.8769126989e-05
#   15 |   0.5149047141 | 7.9814628507e-05 | -1.7822400161e+00 | 4.4783321991e-05
#   16 |   0.5149494975 | -4.5379068122e-05 | -1.7822400161e+00 | 2.5461816428e-05
#   17 |   0.5149240356 | 2.5800099073e-05 | -1.7822400161e+00 | 1.4476220284e-05
#   18 |   0.5149385119 | -1.4668689370e-05 | -1.7822400161e+00 | 8.2304791933e-06
#   19 |   0.5149302814 | 8.3398626424e-06 | -1.7822400161e+00 | 4.6794273313e-06
#   20 |   0.5149349608 | -4.7416317393e-06 | -1.7822400161e+00 | 2.6604899993e-06
#   21 |   0.5149323003 | 2.6958516164e-06 | -1.7822400161e+00 | 1.5126198447e-06
#   22 |   0.5149338129 | -1.5327261947e-06 | -1.7822400161e+00 | 8.5999987698e-07
#   23 |   0.5149329529 | 8.7143084720e-07 | -1.7822400161e+00 | 4.8895257621e-07
#   24 |   0.5149334419 | -4.9545180930e-07 | -1.7822400161e+00 | 2.7799387559e-07
#   25 |   0.5149331639 | 2.8168896149e-07 | -1.7822400161e+00 | 1.5805332554e-07
#   26 |   0.5149333220 | -1.6015418197e-07 | -1.7822400161e+00 | 8.9861174946e-08
#   27 |   0.5149332321 | 9.1055610885e-08 | -1.7822400161e+00 | 5.1090543352e-08
#   28 |   0.5149332832 | -5.1769641241e-08 | -1.7822400161e+00 | 2.9047513728e-08
#   29 |   0.5149332541 | 2.9433614213e-08 | -1.7822400161e+00 | 1.6514955292e-08
#   30 |   0.5149332706 | -1.6734472752e-08 | -1.7822400161e+00 | 9.3895730080e-09
#   31 |   0.5149332613 | 9.5143796175e-09 | -1.7822400161e+00 | 5.3384390242e-09
#   32 |   0.5149332666 | -5.4093978186e-09 | -1.7822400161e+00 | 3.0351680058e-09
#   33 |   0.5149332636 | 3.0755115676e-09 | -1.7822400161e+00 | 1.7256438500e-09
#   34 |   0.5149332653 | -1.7485811687e-09 | -1.7822400161e+00 | 9.8111430091e-10
#   35 |   0.5149332643 | 9.9415536914e-10 | -1.7822400161e+00 | 5.5781224084e-10
#   36 |   0.5149332649 | -5.6522664327e-10 | -1.7822400161e+00 | 3.1714397775e-10
#   37 |   0.5149332645 | 3.2135949457e-10 | -1.7822400161e+00 | 1.8031209859e-10
#   38 |   0.5149332647 | -1.8270873703e-10 | -1.7822400161e+00 | 1.0251632876e-10
#   39 |   0.5149332646 | 1.0387896099e-10 | -1.7822400161e+00 | 5.8285598570e-11
#
# Respuesta final Newton modificado:
# Raiz aproximada = 0.514933264682
# Numero de iteraciones = 40

# %% [markdown]
# # Comparación: Método de Newton vs Newton Modificado
#
# | Aspecto | Newton clásico | Newton modificado |
# |--------|--------------|------------------|
# | Fórmula | $ x_{k+1} = x_k - \frac{f(x_k)}{f'(x_k)} $ | $ x_{k+1} = x_k - \frac{f(x_k)}{f'(x_0)} $ |
# | Uso de la derivada | Se actualiza en cada iteración | Se calcula una sola vez |
# | Velocidad de convergencia | 🚀 Cuadrática (muy rápida) | 🐢 Lineal (más lenta) |
# | Número de iteraciones | Pocas | Muchas |
# | Costo por iteración | Alto (derivada cada vez) | Bajo (derivada fija) |
# | Precisión | Muy alta en pocas iteraciones | Requiere más iteraciones para igual precisión |
# | Estabilidad | Puede fallar si \( f'(x_k) \approx 0 \) | Más estable si la derivada no cambia mucho |
# | Implementación | Más costosa | Más simple |
# | Uso típico | Problemas pequeños o académicos | Problemas grandes o costosos |
# | Ejemplo en gráfica | Caída abrupta del error | Disminución gradual del error |
#
# ---
#
# ## Ventajas
#
# ### Newton clásico
# - Convergencia muy rápida (cuadrática)
# - Alta precisión en pocas iteraciones
# - Método estándar en teoría
#
# ### Newton modificado
# - Menor costo computacional por iteración
# - Más fácil de implementar en problemas grandes
# - Útil cuando la derivada es costosa
#
# ---
#
# ## Desventajas
#
# ### Newton clásico
# - Requiere calcular la derivada en cada iteración
# - Puede ser costoso en problemas grandes
# - Sensible a malas aproximaciones iniciales
#
# ### Newton modificado
# - Convergencia más lenta
# - Puede requerir muchas iteraciones
# - Menor eficiencia global en problemas pequeños
